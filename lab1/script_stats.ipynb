# %%
import pandas as pd
import altair as alt

# %%
oneChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    oneChoiceHundredBins.append(pd.read_csv("./mandatoryExperiments/oneChoiceHundredBins/oneChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,5):
    means.append(oneChoiceHundredBins[i - 1].loc[:,0].mean())
means

hundred_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
        "nBins": [100 for i in range(1,5)],
    }
)
hundred_df
# Out:
#    nBalls  meanGap  nBins
# 0      10    1.297    100
# 1     100    3.243    100
# 2    1000    8.845    100
# 3   10000   25.913    100

# %%
oneChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    oneChoiceThousandBins.append(pd.read_csv("./mandatoryExperiments/oneChoiceThousandBins/oneChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,7):
    means.append(oneChoiceThousandBins[i - 1].loc[:,0].mean())
means

thousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
        "nBins": [1000 for i in range(1,7)],
    }
)
thousand_df
# Out:
#     nBalls  meanGap  nBins
# 0       10    1.036   1000
# 1      100    2.036   1000
# 2     1000    4.488   1000
# 3    10000   11.814   1000
# 4   100000   33.828   1000
# 5  1000000  104.161   1000

# %%
alt.Chart(thousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:N', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
oneChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    oneChoiceTenThousandBins.append(pd.read_csv("./mandatoryExperiments/oneChoiceTenThousandBins/oneChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,9):
    means.append(oneChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

tenThousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
        "nBins": [10000 for i in range(1,9)],
    }
)
tenThousand_df
# Out:
#       nBalls  meanGap  nBins
# 0         10    1.002  10000
# 1        100    1.403  10000
# 2       1000    2.716  10000
# 3      10000    5.691  10000
# 4     100000   14.351  10000
# 5    1000000   40.873  10000
# 6   10000000  124.680  10000
# 7  100000000  386.456  10000

# %%
alt.Chart(tenThousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:N', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
oneChoice_df = pd.concat([tenThousand_df, thousand_df, hundred_df])
oneChoice_df
# Out:
#       nBalls  meanGap  nBins
# 0         10    1.002  10000
# 1        100    1.403  10000
# 2       1000    2.716  10000
# 3      10000    5.691  10000
# 4     100000   14.351  10000
# 5    1000000   40.873  10000
# 6   10000000  124.680  10000
# 7  100000000  386.456  10000
# 0         10    1.036   1000
# 1        100    2.036   1000
# 2       1000    4.488   1000
# 3      10000   11.814   1000
# 4     100000   33.828   1000
# 5    1000000  104.161   1000
# 0         10    1.297    100
# 1        100    3.243    100
# 2       1000    8.845    100
# 3      10000   25.913    100

# %%
twoChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    twoChoiceHundredBins.append(pd.read_csv("./mandatoryExperiments/twoChoiceHundredBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,5):
    means.append(twoChoiceHundredBins[i - 1].loc[:,0].mean())
means

twoChoiceHundred_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
        "nBins": [100 for i in range (1,5)],
    }
)
twoChoiceHundred_df
# Out:
#    nBalls  meanGap  nBins
# 0      10    0.924    100
# 1     100    1.569    100
# 2    1000    1.895    100
# 3   10000    1.907    100

# %%
alt.Chart(twoChoiceHundred_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:Q', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
twoChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    twoChoiceThousandBins.append(pd.read_csv("./mandatoryExperiments/twoChoiceThousandBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,7):
    means.append(twoChoiceThousandBins[i - 1].loc[:,0].mean())
means

twoChoiceThousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
        "nBins": [1000 for i in range (1,7)],
    }
)
#twoChoiceThousand_df.to_csv("./mandatoryExperiments/twoChoiceThousandBins/means.csv")
twoChoiceThousand_df
# Out:
#     nBalls  meanGap  nBins
# 0       10    0.990   1000
# 1      100    1.173   1000
# 2     1000    2.006   1000
# 3    10000    2.086   1000
# 4   100000    2.058   1000
# 5  1000000    2.082   1000

# %%
alt.Chart(twoChoiceThousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:Q', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
twoChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    twoChoiceTenThousandBins.append(pd.read_csv("./mandatoryExperiments/twoChoiceTenThousandBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,9):
    means.append(twoChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

twoChoiceTenThousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
        "nBins": [10000 for i in range (1,9)],
    }
)
#twoChoiceTenThousand_df.to_csv("./mandatoryExperiments/twoChoiceTenThousandBins/means.csv")
twoChoiceTenThousand_df
# Out:
#       nBalls  meanGap  nBins
# 0         10    0.999  10000
# 1        100    0.994  10000
# 2       1000    1.860  10000
# 3      10000    2.056  10000
# 4     100000    2.505  10000
# 5    1000000    2.520  10000
# 6   10000000    2.513  10000
# 7  100000000    2.535  10000

# %%
alt.Chart(twoChoiceTenThousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:N', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
twoChoice_df = pd.concat([twoChoiceTenThousand_df, twoChoiceThousand_df, twoChoiceHundred_df])
twoChoice_df
# Out:
#       nBalls  meanGap  nBins
# 0         10    0.999  10000
# 1        100    0.994  10000
# 2       1000    1.860  10000
# 3      10000    2.056  10000
# 4     100000    2.505  10000
# 5    1000000    2.520  10000
# 6   10000000    2.513  10000
# 7  100000000    2.535  10000
# 0         10    0.990   1000
# 1        100    1.173   1000
# 2       1000    2.006   1000
# 3      10000    2.086   1000
# 4     100000    2.058   1000
# 5    1000000    2.082   1000
# 0         10    0.924    100
# 1        100    1.569    100
# 2       1000    1.895    100
# 3      10000    1.907    100

# %%
betaChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    betaChoiceHundredBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceHundredBins/betaChoice" + f"{n}" + "-0.25.txt", header=None))

means = []
for i in range(1,5):
    means.append(betaChoiceHundredBins[i - 1].loc[:,0].mean())
means

betaChoiceHundredBins025_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
        "nBins": [100 for i in range(1,5)],
        "beta": [0.25 for i in range(1,5)],
    }
)
betaChoiceHundredBins025_df
# Out:
#    nBalls  meanGap  nBins  beta
# 0      10    1.183    100  0.25
# 1     100    2.824    100  0.25
# 2    1000    6.295    100  0.25
# 3   10000    9.672    100  0.25

# %%
betaChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    betaChoiceHundredBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceHundredBins/betaChoice" + f"{n}" + "-0.5.txt", header=None))

means = []
for i in range(1,5):
    means.append(betaChoiceHundredBins[i - 1].loc[:,0].mean())
means

betaChoiceHundredBins05_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
        "nBins": [100 for i in range(1,5)],
        "beta": [0.5 for i in range(1,5)],
    }
)
betaChoiceHundredBins05_df
# Out:
#    nBalls  meanGap  nBins  beta
# 0      10    1.133    100   0.5
# 1     100    2.457    100   0.5
# 2    1000    4.260    100   0.5
# 3   10000    4.578    100   0.5

# %%
betaChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    betaChoiceHundredBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceHundredBins/betaChoice" + f"{n}" + "-0.75.txt", header=None))

means = []
for i in range(1,5):
    means.append(betaChoiceHundredBins[i - 1].loc[:,0].mean())
means

betaChoiceHundredBins075_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
        "nBins": [100 for i in range(1,5)],
        "beta": [0.75 for i in range(1,5)],
    }
)
betaChoiceHundredBins075_df
# Out:
#    nBalls  meanGap  nBins  beta
# 0      10    1.012    100  0.75
# 1     100    2.064    100  0.75
# 2    1000    2.737    100  0.75
# 3   10000    2.743    100  0.75

# %%
betaChoiceHundredBins_df = pd.concat([betaChoiceHundredBins025_df, betaChoiceHundredBins05_df, betaChoiceHundredBins075_df])
betaChoiceHundredBins_df
# Out:
#    nBalls  meanGap  nBins  beta
# 0      10    1.183    100  0.25
# 1     100    2.824    100  0.25
# 2    1000    6.295    100  0.25
# 3   10000    9.672    100  0.25
# 0      10    1.133    100  0.50
# 1     100    2.457    100  0.50
# 2    1000    4.260    100  0.50
# 3   10000    4.578    100  0.50
# 0      10    1.012    100  0.75
# 1     100    2.064    100  0.75
# 2    1000    2.737    100  0.75
# 3   10000    2.743    100  0.75

# %%
betaChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    betaChoiceThousandBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceThousandBins/betaChoice" + f"{n}" + "-0.25.txt", header=None))

means = []
for i in range(1,7):
    means.append(betaChoiceThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceThousandBins025_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
        "nBins": [1000 for i in range(1,7)],
        "beta": [0.25 for i in range(1,7)],
    }
)
betaChoiceThousandBins025_df
# Out:
#     nBalls  meanGap  nBins  beta
# 0       10    1.020   1000  0.25
# 1      100    1.964   1000  0.25
# 2     1000    3.984   1000  0.25
# 3    10000    8.724   1000  0.25
# 4   100000   13.812   1000  0.25
# 5  1000000   13.888   1000  0.25

# %%
betaChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    betaChoiceThousandBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceThousandBins/betaChoice" + f"{n}" + "-0.5.txt", header=None))

means = []
for i in range(1,7):
    means.append(betaChoiceThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceThousandBins05_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
        "nBins": [1000 for i in range(1,7)],
        "beta": [0.5 for i in range(1,7)],
    }
)
betaChoiceThousandBins05_df
# Out:
#     nBalls  meanGap  nBins  beta
# 0       10    1.010   1000   0.5
# 1      100    1.873   1000   0.5
# 2     1000    3.413   1000   0.5
# 3    10000    5.904   1000   0.5
# 4   100000    6.444   1000   0.5
# 5  1000000    6.425   1000   0.5

# %%
betaChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    betaChoiceThousandBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceThousandBins/betaChoice" + f"{n}" + "-0.75.txt", header=None))

means = []
for i in range(1,7):
    means.append(betaChoiceThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceThousandBins075_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
        "nBins": [1000 for i in range(1,7)],
        "beta": [0.75 for i in range(1,7)],
    }
)
betaChoiceThousandBins075_df
# Out:
#     nBalls  meanGap  nBins  beta
# 0       10    1.000   1000  0.75
# 1      100    1.709   1000  0.75
# 2     1000    2.802   1000  0.75
# 3    10000    3.742   1000  0.75
# 4   100000    3.778   1000  0.75
# 5  1000000    3.784   1000  0.75

# %%
betaChoiceThousandBins_df = pd.concat([betaChoiceThousandBins025_df, betaChoiceThousandBins05_df, betaChoiceThousandBins075_df])
betaChoiceThousandBins_df.to_csv("./mandatoryExperiments/betaChoiceThousandBins/means.csv")

# %%
betaChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    betaChoiceTenThousandBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceTenThousandBins/betaChoice" + f"{n}" + "-0.25.txt", header=None))

means = []
for i in range(1,9):
    means.append(betaChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceTenThousandBins025_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
        "nBins": [10000 for i in range(1,9)],
        "beta": [0.25 for i in range(1,9)],
    }
)
betaChoiceTenThousandBins025_df
# Out:
#       nBalls  meanGap  nBins  beta
# 0         10    1.000  10000  0.25
# 1        100    1.281  10000  0.25
# 2       1000    2.490  10000  0.25
# 3      10000    5.092  10000  0.25
# 4     100000   10.803  10000  0.25
# 5    1000000   17.704  10000  0.25
# 6   10000000   18.243  10000  0.25
# 7  100000000   18.189  10000  0.25

# %%
betaChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    betaChoiceTenThousandBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceTenThousandBins/betaChoice" + f"{n}" + "-0.5.txt", header=None))

means = []
for i in range(1,9):
    means.append(betaChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceTenThousandBins05_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
        "nBins": [10000 for i in range(1,9)],
        "beta": [0.5 for i in range(1,9)],
    }
)
betaChoiceTenThousandBins05_df
# Out:
#       nBalls  meanGap  nBins  beta
# 0         10    0.999  10000   0.5
# 1        100    1.211  10000   0.5
# 2       1000    2.240  10000   0.5
# 3      10000    4.337  10000   0.5
# 4     100000    7.490  10000   0.5
# 5    1000000    8.241  10000   0.5
# 6   10000000    8.246  10000   0.5
# 7  100000000    8.275  10000   0.5

# %%
betaChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    betaChoiceTenThousandBins.append(pd.read_csv("./mandatoryExperiments/betaChoiceTenThousandBins/betaChoice" + f"{n}" + "-0.75.txt", header=None))

means = []
for i in range(1,9):
    means.append(betaChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceTenThousandBins075_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
        "nBins": [10000 for i in range(1,9)],
        "beta": [0.75 for i in range(1,9)],
    }
)
betaChoiceTenThousandBins075_df
# Out:
#       nBalls  meanGap  nBins  beta
# 0         10    1.000  10000  0.75
# 1        100    1.091  10000  0.75
# 2       1000    2.017  10000  0.75
# 3      10000    3.479  10000  0.75
# 4     100000    4.694  10000  0.75
# 5    1000000    4.777  10000  0.75
# 6   10000000    4.759  10000  0.75
# 7  100000000    4.761  10000  0.75

# %%
betaChoiceTenThousandBins_df = pd.concat([betaChoiceTenThousandBins025_df, betaChoiceTenThousandBins05_df, betaChoiceTenThousandBins075_df])
betaChoiceTenThousandBins_df.to_csv("./mandatoryExperiments/betaChoiceTenThousandBins/means.csv")

# %%
#oneChoice_beta_df = oneChoice_df.insert(3, "beta", [0 for i in range(0,len(oneChoice_df['nBins']))])
oneChoice_df
# Out:
#       nBalls  meanGap  nBins  beta
# 0         10    1.002  10000     0
# 1        100    1.403  10000     0
# 2       1000    2.716  10000     0
# 3      10000    5.691  10000     0
# 4     100000   14.351  10000     0
# 5    1000000   40.873  10000     0
# 6   10000000  124.680  10000     0
# 7  100000000  386.456  10000     0
# 0         10    1.036   1000     0
# 1        100    2.036   1000     0
# 2       1000    4.488   1000     0
# 3      10000   11.814   1000     0
# 4     100000   33.828   1000     0
# 5    1000000  104.161   1000     0
# 0         10    1.297    100     0
# 1        100    3.243    100     0
# 2       1000    8.845    100     0
# 3      10000   25.913    100     0

# %%
twoChoice_df
# Out:
#       nBalls  meanGap  nBins  beta
# 0         10    0.999  10000     1
# 1        100    0.994  10000     1
# 2       1000    1.860  10000     1
# 3      10000    2.056  10000     1
# 4     100000    2.505  10000     1
# 5    1000000    2.520  10000     1
# 6   10000000    2.513  10000     1
# 7  100000000    2.535  10000     1
# 0         10    0.990   1000     1
# 1        100    1.173   1000     1
# 2       1000    2.006   1000     1
# 3      10000    2.086   1000     1
# 4     100000    2.058   1000     1
# 5    1000000    2.082   1000     1
# 0         10    0.924    100     1
# 1        100    1.569    100     1
# 2       1000    1.895    100     1
# 3      10000    1.907    100     1

# %%
mandatoryExperiments_df = pd.concat([oneChoice_df,twoChoice_df, betaChoiceHundredBins_df, betaChoiceThousandBins_df, betaChoiceTenThousandBins_df])
pd.set_option('display.max_rows', 500)
mandatoryExperiments_df.sort_values(by=['nBalls','nBins','beta'])
# Out:
#       nBalls  meanGap  nBins  beta
# 0         10    1.297    100  0.00
# 0         10    1.183    100  0.25
# 0         10    1.133    100  0.50
# 0         10    1.012    100  0.75
# 0         10    0.924    100  1.00
# 0         10    1.036   1000  0.00
# 0         10    1.020   1000  0.25
# 0         10    1.010   1000  0.50
# 0         10    1.000   1000  0.75
# 0         10    0.990   1000  1.00
# 0         10    1.002  10000  0.00
# 0         10    1.000  10000  0.25
# 0         10    0.999  10000  0.50
# 0         10    1.000  10000  0.75
# 0         10    0.999  10000  1.00
# 1        100    3.243    100  0.00
# 1        100    2.824    100  0.25
# 1        100    2.457    100  0.50
# 1        100    2.064    100  0.75
# 1        100    1.569    100  1.00
# 1        100    2.036   1000  0.00
# 1        100    1.964   1000  0.25
# 1        100    1.873   1000  0.50
# 1        100    1.709   1000  0.75
# 1        100    1.173   1000  1.00
# 1        100    1.403  10000  0.00
# ...

# %%
mandatoryExperiments_df.to_csv("./mandatoryExperiments/globalmeans.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
oneChoiceHundredBins = []
for per in percs:
    for i in range (2,5):
        n = 10**i
        oneChoiceHundredBins.append(pd.read_csv("./batchedExperiments/oneChoiceHundredBins/oneChoice" + f"{n}" + "-" f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
for j in range(0,len(percs)):
    for i in range(0,3):
        idx = i + 3*j
        means.append(oneChoiceHundredBins[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        batched_per.append(percs[j])

hundred_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [100 for i in range(0,len(means))],
        "batchPercentage": batched_per,
    }
)
hundred_df.to_csv("./batchedExperiments/oneChoiceHundredBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
base_df = []
for per in percs:
    for i in range (2,7):
        n = 10**i
        base_df.append(pd.read_csv("./batchedExperiments/oneChoiceThousandBins/oneChoice" + f"{n}" + "-" f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
for j in range(0,len(percs)):
    for i in range(0,5):
        idx = i + 5*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        batched_per.append(percs[j])

thousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [1000 for i in range(0,len(means))],
        "batchPercentage": batched_per,
    }
)
thousand_df.to_csv("./batchedExperiments/oneChoiceThousandBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
base_df = []
for per in percs:
    for i in range (2,9):
        n = 10**i
        base_df.append(pd.read_csv("./batchedExperiments/oneChoiceTenThousandBins/oneChoice" + f"{n}" + "-" f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
for j in range(0,len(percs)):
    for i in range(0,7):
        idx = i + 7*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        batched_per.append(percs[j])

tenThousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [10000 for i in range(0,len(means))],
        "batchPercentage": batched_per,
    }
)
tenThousand_df.to_csv("./batchedExperiments/oneChoiceTenThousandBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
base_df = []
for per in percs:
    for i in range (2,5):
        n = 10**i
        base_df.append(pd.read_csv("./batchedExperiments/twoChoiceHundredBins/twoChoice" + f"{n}" + "-" f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
for j in range(0,len(percs)):
    for i in range(0,3):
        idx = i + 3*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        batched_per.append(percs[j])

twoChoiceHundred_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [100 for i in range(0,len(means))],
        "batchPercentage": batched_per,
    }
)
twoChoiceHundred_df.to_csv("./batchedExperiments/twoChoiceHundredBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
base_df = []
for per in percs:
    for i in range (2,7):
        n = 10**i
        base_df.append(pd.read_csv("./batchedExperiments/twoChoiceThousandBins/twoChoice" + f"{n}" + "-" f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
for j in range(0,len(percs)):
    for i in range(0,5):
        idx = i + 5*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        batched_per.append(percs[j])

twoChoiceThousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [1000 for i in range(0,len(means))],
        "batchPercentage": batched_per,
    }
)
twoChoiceThousand_df.to_csv("./batchedExperiments/twoChoiceThousandBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
base_df = []
for per in percs:
    for i in range (2,9):
        n = 10**i
        base_df.append(pd.read_csv("./batchedExperiments/twoChoiceTenThousandBins/twoChoice" + f"{n}" + "-" f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
for j in range(0,len(percs)):
    for i in range(0,7):
        idx = i + 7*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        batched_per.append(percs[j])

twoChoiceTenThousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [10000 for i in range(0,len(means))],
        "batchPercentage": batched_per,
    }
)
twoChoiceTenThousand_df.to_csv("./batchedExperiments/twoChoiceTenThousandBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
betas = ["0.25", "0.5", "0.75"]
base_df = []
for beta in betas:
    for per in percs:
        for i in range (2,5):
            n = 10**i
            base_df.append(pd.read_csv("./batchedExperiments/betaChoiceHundredBins/betaChoice" + f"{n}" + "-" + beta + "-" + f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
beta_val = []
for k in range(0,len(betas)):
    for j in range(0,len(percs)):
        for i in range(0,3):
            idx = i + 3*j + 3*len(percs)*k
            means.append(base_df[idx].loc[:,0].mean())
            balls.append(10**(i + 2))
            batched_per.append(percs[j])
            beta_val.append(betas[k])

betaChoiceHundred_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [100 for i in range(0,len(means))],
        "batchPercentage": batched_per,
        "beta": beta_val,
    }
)
betaChoiceHundred_df.to_csv("./batchedExperiments/betaChoiceHundredBins/means.csv")
# Out:
#     nBalls  meanGap  nBins  batchPercentage  beta
# 0      100    2.840    100             0.01  0.25
# 1     1000    6.395    100             0.01  0.25
# 2    10000    9.615    100             0.01  0.25
# 3      100    2.890    100             0.05  0.25
# 4     1000    6.280    100             0.05  0.25
# 5    10000   10.670    100             0.05  0.25
# 6      100    2.755    100             0.10  0.25
# 7     1000    6.525    100             0.10  0.25
# 8    10000   11.145    100             0.10  0.25
# 9      100    3.040    100             0.50  0.25
# 10    1000    7.385    100             0.50  0.25
# 11   10000   19.100    100             0.50  0.25
# 12     100    3.200    100             1.00  0.25
# 13    1000    8.765    100             1.00  0.25
# 14   10000   26.500    100             1.00  0.25
# 15     100    2.390    100             0.01   0.5
# 16    1000    4.235    100             0.01   0.5
# 17   10000    4.885    100             0.01   0.5
# ...

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
betas = ["0.25", "0.5", "0.75"]
base_df = []
for beta in betas:
    for per in percs:
        for i in range (2,7):
            n = 10**i
            base_df.append(pd.read_csv("./batchedExperiments/betaChoiceThousandBins/betaChoice" + f"{n}" + "-" + beta + "-" + f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
beta_val = []
for k in range(0,len(betas)):
    for j in range(0,len(percs)):
        for i in range(0,5):
            idx = i + 5*j + 5*len(percs)*k
            means.append(base_df[idx].loc[:,0].mean())
            balls.append(10**(i + 2))
            batched_per.append(percs[j])
            beta_val.append(betas[k])

betaChoiceThousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [1000 for i in range(0,len(means))],
        "batchPercentage": batched_per,
        "beta": beta_val,
    }
)
betaChoiceThousand_df.to_csv("./batchedExperiments/betaChoiceThousandBins/means.csv")

# %%
percs = [0.01, 0.05, 0.10, 0.50, 1.00]
betas = ["0.25", "0.5", "0.75"]
base_df = []
for beta in betas:
    for per in percs:
        for i in range (2,9):
            n = 10**i
            base_df.append(pd.read_csv("./batchedExperiments/betaChoiceTenThousandBins/betaChoice" + f"{n}" + "-" + beta + "-" + f"{per:.2f}" + ".txt", header=None))
    
means = []
balls = []
batched_per = []
beta_val = []
for k in range(0,len(betas)):
    for j in range(0,len(percs)):
        for i in range(0,7):
            idx = i + 7*j + 7*len(percs)*k
            means.append(base_df[idx].loc[:,0].mean())
            balls.append(10**(i + 2))
            batched_per.append(percs[j])
            beta_val.append(betas[k])

betaChoiceTenThousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [10000 for i in range(0,len(means))],
        "batchPercentage": batched_per,
        "beta": beta_val,
    }
)
betaChoiceTenThousand_df.to_csv("./batchedExperiments/betaChoiceTenThousandBins/means.csv")

# %%
oneChoice_df = pd.concat([hundred_df,thousand_df,tenThousand_df])
oneChoice_df.insert(4, "beta", [0 for i in range(0,len(oneChoice_df['nBins']))])
oneChoice_df
# Out:
#        nBalls  meanGap  nBins  batchPercentage  beta
# 0         100    1.560    100             0.01     0
# 1        1000    2.015    100             0.01     0
# 2       10000    3.235    100             0.01     0
# 3         100    1.675    100             0.05     0
# 4        1000    2.515    100             0.05     0
# ..        ...      ...    ...              ...   ...
# 30      10000    5.700  10000             1.00     0
# 31     100000   14.275  10000             1.00     0
# 32    1000000   41.090  10000             1.00     0
# 33   10000000  125.605  10000             1.00     0
# 34  100000000  385.980  10000             1.00     0
#
# [75 rows x 5 columns]

# %%
twoChoice_df = pd.concat([twoChoiceHundred_df,twoChoiceThousand_df,twoChoiceTenThousand_df])
twoChoice_df.insert(4, "beta", [0 for i in range(0,len(oneChoice_df['nBins']))])
twoChoice_df
# Out:
#        nBalls  meanGap  nBins  batchPercentage  beta
# 0         100    1.600    100             0.01     0
# 1        1000    2.055    100             0.01     0
# 2       10000    3.290    100             0.01     0
# 3         100    1.730    100             0.05     0
# 4        1000    2.565    100             0.05     0
# ..        ...      ...    ...              ...   ...
# 30      10000    5.730  10000             1.00     0
# 31     100000   14.375  10000             1.00     0
# 32    1000000   40.515  10000             1.00     0
# 33   10000000  124.585  10000             1.00     0
# 34  100000000  389.525  10000             1.00     0
#
# [75 rows x 5 columns]

# %%
batched_df = pd.concat([oneChoice_df,twoChoice_df, betaChoiceHundred_df, betaChoiceThousand_df, betaChoiceTenThousand_df])
batched_df
# Out:
#         nBalls  meanGap  nBins  batchPercentage  beta
# 0          100    1.560    100             0.01     0
# 1         1000    2.015    100             0.01     0
# 2        10000    3.235    100             0.01     0
# 3          100    1.675    100             0.05     0
# 4         1000    2.515    100             0.05     0
# ..         ...      ...    ...              ...   ...
# 100      10000    5.660  10000             1.00  0.75
# 101     100000   14.295  10000             1.00  0.75
# 102    1000000   40.790  10000             1.00  0.75
# 103   10000000  124.160  10000             1.00  0.75
# 104  100000000  387.195  10000             1.00  0.75
#
# [375 rows x 5 columns]

# %%
batched_df.to_csv("./batchedExperiments/generalMeans.csv")

# %%
base_df = []
for k in [1,2]:
    for i in range (1,5):
        n = 10**i
        base_df.append(pd.read_csv("./queryExperiments/queryOneHundredBins/experiment" + f"{n}" + "-" f"{k}" + ".txt", header=None))
    
means = []
balls = []
queries = []
for j in range(0,2):
    for i in range(0,4):
        idx = i + 4*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        queries.append(j + 1)

hundred_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [101 for i in range(0,len(means))],
        "queries": queries,
    }
)
hundred_df.to_csv("./queryExperiments/queryOneHundredBins/means.csv")

# %%
base_df = []
for k in [1,2]:
    for i in range (1,7):
        n = 10**i
        base_df.append(pd.read_csv("./queryExperiments/queryOneThousandBins/experiment" + f"{n}" + "-" f"{k}" + ".txt", header=None))
    
means = []
balls = []
queries = []
for j in range(0,2):
    for i in range(0,6):
        idx = i + 6*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        queries.append(j + 1)

thousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [1001 for i in range(0,len(means))],
        "queries": queries,
    }
)
thousand_df.to_csv("./queryExperiments/queryOneThousandBins/means.csv")

# %%
base_df = []
for k in [1,2]:
    for i in range (1,7):
        n = 10**i
        base_df.append(pd.read_csv("./queryExperiments/queryOneTenThousandBins/experiment" + f"{n}" + "-" f"{k}" + ".txt", header=None))
    
means = []
balls = []
queries = []
for j in range(0,2):
    for i in range(0,6):
        idx = i + 6*j
        means.append(base_df[idx].loc[:,0].mean())
        balls.append(10**(i + 2))
        queries.append(j + 1)

tenThousand_df = pd.DataFrame(
    {
        "nBalls": balls,
        "meanGap": means,
        "nBins": [3001 for i in range(0,len(means))],
        "queries": queries,
    }
)
tenThousand_df.to_csv("./queryExperiments/queryOneTenThousandBins/means.csv")

# %%
queryExperiments_df = pd.concat([hundred_df,thousand_df,tenThousand_df])
queryExperiments_df.to_csv("./queryExperiments/generalMeans.csv")
