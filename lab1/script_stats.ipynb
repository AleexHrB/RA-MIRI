# %%
import pandas as pd
import altair as alt

# %%
oneChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    oneChoiceHundredBins.append(pd.read_csv("./oneChoiceHundredBins/oneChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,5):
    means.append(oneChoiceHundredBins[i - 1].loc[:,0].mean())
means

hundred_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
    }
)
hundred_df
# Out:
#    nBalls    meanGap
# 0      10   1.286957
# 1     100   3.230435
# 2    1000   8.823785
# 3   10000  25.944888

# %%
oneChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    oneChoiceThousandBins.append(pd.read_csv("./oneChoiceThousandBins/oneChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,7):
    means.append(oneChoiceThousandBins[i - 1].loc[:,0].mean())
means

thousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
    }
)
thousand_df.to_csv("./oneChoiceThousandBins/means.csv")

# %%
alt.Chart(thousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:N', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
oneChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    oneChoiceTenThousandBins.append(pd.read_csv("./oneChoiceTenThousandBins/oneChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,9):
    means.append(oneChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

tenThousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
    }
)
tenThousand_df.to_csv("./oneChoiceTenThousandBins/means.csv")

# %%
alt.Chart(tenThousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:N', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
twoChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    twoChoiceHundredBins.append(pd.read_csv("./twoChoiceHundredBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,5):
    means.append(twoChoiceHundredBins[i - 1].loc[:,0].mean())
means

twoChoiceHundred_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
    }
)
twoChoiceHundred_df.to_csv("./twoChoiceHundredBins/means.csv")

# %%
alt.Chart(twoChoiceHundred_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:Q', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
twoChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    twoChoiceThousandBins.append(pd.read_csv("./twoChoiceThousandBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,7):
    means.append(twoChoiceThousandBins[i - 1].loc[:,0].mean())
means

twoChoiceThousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
    }
)
twoChoiceThousand_df.to_csv("./twoChoiceThousandBins/means.csv")

# %%
alt.Chart(twoChoiceThousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:Q', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
twoChoiceTenThousandBins = []
for i in range (1,9):
    n = 10**i
    twoChoiceTenThousandBins.append(pd.read_csv("./twoChoiceTenThousandBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,9):
    means.append(twoChoiceTenThousandBins[i - 1].loc[:,0].mean())
means

twoChoiceTenThousand_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,9)],
        "meanGap": means,
    }
)
twoChoiceTenThousand_df.to_csv("./twoChoiceTenThousandBins/means.csv")
# Out:
#       nBalls  meanGap
# 0         10    0.999
# 1        100    0.994
# 2       1000    1.860
# 3      10000    2.056
# 4     100000    2.505
# 5    1000000    2.520
# 6   10000000    2.513
# 7  100000000    2.535

# %%
alt.Chart(twoChoiceTenThousand_df).mark_line(point=alt.OverlayMarkDef(filled=False, fill="white")).encode(
    x=alt.X('nBalls:N', title='Number of balls'),
    y=alt.Y('meanGap:Q', title='Mean Gap'),
    tooltip= [alt.Tooltip('nBalls:N',title='Number of balls'), alt.Tooltip('meanGap:Q', title='Mean Gap')],
).properties(
    title='Thousand Bins'
)
# Out:
# alt.Chart(...)

# %%
betaChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    betaChoiceHundredBins.append(pd.read_csv("./betaChoiceHundredBins/betaChoice" + f"{n}" + "-0.25.txt", header=None))

means = []
for i in range(1,5):
    means.append(betaChoiceHundredBins[i - 1].loc[:,0].mean())
means

betaChoiceHundredBins025_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
    }
)
betaChoiceHundredBins025_df.to_csv("./betaChoiceHundredBins/mean025.csv")

# %%
betaChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    betaChoiceHundredBins.append(pd.read_csv("./betaChoiceHundredBins/betaChoice" + f"{n}" + "-0.5.txt", header=None))

means = []
for i in range(1,5):
    means.append(betaChoiceHundredBins[i - 1].loc[:,0].mean())
means

betaChoiceHundredBins05_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
    }
)
betaChoiceHundredBins05_df.to_csv("./betaChoiceHundredBins/mean05.csv")

# %%
betaChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    betaChoiceHundredBins.append(pd.read_csv("./betaChoiceHundredBins/betaChoice" + f"{n}" + "-0.75.txt", header=None))

means = []
for i in range(1,5):
    means.append(betaChoiceHundredBins[i - 1].loc[:,0].mean())
means

betaChoiceHundredBins075_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
    }
)
betaChoiceHundredBins075_df.to_csv("./betaChoiceHundredBins/mean075.csv")

# %%
betaChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    betaChoiceThousandBins.append(pd.read_csv("./betaChoiceThousandBins/betaChoice" + f"{n}" + "-0.25.txt", header=None))

means = []
for i in range(1,7):
    means.append(betaChoiceThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceThousandBins025_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
    }
)
betaChoiceThousandBins025_df
# Out:
#     nBalls  meanGap
# 0       10    1.020
# 1      100    1.964
# 2     1000    3.984
# 3    10000    8.724
# 4   100000   13.812
# 5  1000000   13.888

# %%
betaChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    betaChoiceThousandBins.append(pd.read_csv("./betaChoiceThousandBins/betaChoice" + f"{n}" + "-0.5.txt", header=None))

means = []
for i in range(1,7):
    means.append(betaChoiceThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceThousandBins05_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
    }
)
betaChoiceThousandBins05_df
# Out:
#     nBalls  meanGap
# 0       10    1.010
# 1      100    1.873
# 2     1000    3.413
# 3    10000    5.904
# 4   100000    6.444
# 5  1000000    6.425

# %%
betaChoiceThousandBins = []
for i in range (1,7):
    n = 10**i
    betaChoiceThousandBins.append(pd.read_csv("./betaChoiceThousandBins/betaChoice" + f"{n}" + "-0.75.txt", header=None))

means = []
for i in range(1,7):
    means.append(betaChoiceThousandBins[i - 1].loc[:,0].mean())
means

betaChoiceThousandBins075_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,7)],
        "meanGap": means,
    }
)
betaChoiceThousandBins075_df.to_csv("./betaChoiceThousandBins/mean075.csv")

# %%
oneChoiceHundredBins = []
for i in range (1,5):
    n = 10**i
    twoChoiceHundredBins.append(pd.read_csv("./batchedExperiments/oneChoiceHundredBins/twoChoice" + f"{n}" + ".txt", header=None))

means = []
for i in range(1,5):
    means.append(twoChoiceHundredBins[i - 1].loc[:,0].mean())
means

twoChoiceHundred_df = pd.DataFrame(
    {
        "nBalls": [10**i for i in range(1,5)],
        "meanGap": means,
    }
)
twoChoiceHundred_df.to_csv("./twoChoiceHundredBins/means.csv")
